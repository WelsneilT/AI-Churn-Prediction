# %%
import os
import pandas as pd
import seaborn as sns

file_path = r"D:/Documents/IAI-UET/AI - Churn Prediction/dataset/a_IBM Telco Customers Churn Datasets.xlsx"
xls = pd.ExcelFile(file_path)
xls.sheet_names
# Out:
# ['Customer_Info',
#  'Service_Options',
#  'Online_Services',
#  'Payment_Info',
#  'Status_Analysis',
#  'Location_Data',
#  'Population',
#  'Telco_Churn']

# %%
# Hàm chỉ chuẩn hóa tên cột (không ảnh hưởng đến dữ liệu)
def clean_column_names(df):
    """Chuyển tên cột thành chữ thường, thay dấu cách bằng dấu gạch dưới."""
    df.columns = df.columns.str.lower().str.replace(" ", "_")
    return df

# Đọc dữ liệu từ tất cả các sheet và chỉ chuẩn hóa tên cột
df_customer_info = clean_column_names(pd.read_excel(xls, sheet_name="Customer_Info"))
df_service_options = clean_column_names(pd.read_excel(xls, sheet_name="Service_Options"))
df_online_services = clean_column_names(pd.read_excel(xls, sheet_name="Online_Services"))
df_payment_info = clean_column_names(pd.read_excel(xls, sheet_name="Payment_Info"))
df_status_analysis = clean_column_names(pd.read_excel(xls, sheet_name="Status_Analysis"))
df_location_data = clean_column_names(pd.read_excel(xls, sheet_name="Location_Data"))
df_population = clean_column_names(pd.read_excel(xls, sheet_name="Population"))
df_telco_churn = clean_column_names(pd.read_excel(xls, sheet_name="Telco_Churn"))

# Merge dữ liệu theo customer_id, tránh trùng lặp cột
df_merged = df_customer_info \
    .merge(df_service_options, on="customer_id", how="left") \
    .merge(df_online_services.drop(columns=["phone_service", "internet_service"]), on="customer_id", how="left") \
    .merge(df_payment_info, on="customer_id", how="left") \
    .merge(df_status_analysis, on="customer_id", how="left") \
    .merge(df_location_data, on="customer_id", how="left") \
    .merge(df_population.drop(columns=["population_id"]), on="zip_code", how="left") \
    .merge(df_telco_churn.drop(columns=[
        "count", "quarter", "referred_a_friend", "number_of_referrals",
        "tenure_in_months", "offer", "phone_service", "avg_monthly_long_distance_charges",
        "multiple_lines", "internet_service", "internet_type", "avg_monthly_gb_download",
        "online_security", "online_backup", "device_protection_plan", "premium_tech_support",
        "streaming_tv", "streaming_movies", "streaming_music", "unlimited_data",
        "contract", "paperless_billing", "payment_method", "total_charges",
        "total_refunds", "total_extra_data_charges", "total_long_distance_charges",
        "total_revenue"
    ]), on="customer_id", how="left")



# Hiển thị thông tin file đã tạo
df_merged.head()
# Out:
#   customer_id  gender  age under_30 senior_citizen partner dependents  \
# 0  0002-ORFBO  Female   37       No             No     Yes         No
# 1  0003-MKNFE    Male   46       No             No      No         No
# 2  0004-TLHLJ    Male   50       No             No      No         No
# 3  0011-IGKFF    Male   78       No            Yes     Yes         No
# 4  0013-EXCHZ  Female   75       No            Yes     Yes         No
#
#    number_of_dependents married  tenure internet_service phone_service  \
# 0                     0     Yes       9              Yes           Yes
# 1                     0      No       9              Yes           Yes
# 2                     0      No       4              Yes           Yes
# 3                     0     Yes      13              Yes           Yes
# 4                     0     Yes       3              Yes           Yes
#
#   multiple_lines  avg_monthly_gb_download unlimited_data    offer  \
# 0             No                       16            Yes     None
# 1            Yes                       10             No     None
# 2             No                       30            Yes  Offer E
# 3             No                        4            Yes  Offer D
# 4             No                       11            Yes     None
#
#   referred_a_friend  number_of_referrals online_security online_backup  \
# 0               Yes                    2              No           Yes
# 1                No                    0              No            No
# 2                No                    0              No            No
# 3               Yes                    1              No           Yes
# 4               Yes                    3              No            No
#
#   device_protection premium_tech_support streaming_tv streaming_movies  \
# 0                No                  Yes          Yes               No
# 1                No                   No           No              Yes
# 2               Yes                   No           No               No
# 3               Yes                   No          Yes              Yes
# 4                No                  Yes          Yes               No
#
#   streaming_music internet_type        contract paperless_billing  \
# 0              No         Cable        One Year               Yes
# 1             Yes         Cable  Month-to-Month                No
# 2              No   Fiber Optic  Month-to-Month               Yes
# 3              No   Fiber Optic  Month-to-Month               Yes
# 4              No   Fiber Optic  Month-to-Month               Yes
#
#      payment_method  monthly__charges  avg_monthly_long_distance_charges  \
# 0      Mailed check              65.6                              42.39
# 1      Mailed check              59.9                              10.69
# 2  Electronic check              73.9                              33.65
# 3  Electronic check              98.0                              27.82
# 4      Mailed check              83.9                               7.38
#
#    total_charges  total_refunds  total_extra_data_charges  \
# 0         593.30           0.00                         0
# 1         542.40          38.33                        10
# 2         280.85           0.00                         0
# 3        1237.85           0.00                         0
# 4         267.40           0.00                         0
#
#    total_long_distance_charges  total_revenue  satisfaction_score  cltv  \
# 0                       381.51         974.81                   3  2205
# 1                        96.21         610.28                   5  5414
# 2                       134.60         415.45                   1  4479
# 3                       361.66        1599.51                   1  3714
# 4                        22.14         289.54                   1  3464
#
#   customer_status  churn_score churn_label  churn_value   churn_category  \
# 0          Stayed           65          No            0   Not Applicable
# 1          Stayed           66          No            0   Not Applicable
# 2         Churned           71         Yes            1       Competitor
# 3         Churned           91         Yes            1  Dissatisfaction
# 4         Churned           68         Yes            1  Dissatisfaction
#
#                     churn_reason        country       state          city  \
# 0                            NaN  United States  California  Frazier Park
# 1                            NaN  United States  California      Glendale
# 2  Competitor had better devices  United States  California    Costa Mesa
# 3        Product dissatisfaction  United States  California      Martinez
# 4            Network reliability  United States  California     Camarillo
#
#    zip_code  total_population   latitude   longitude  population  \
# 0     93225              4498  34.827662 -118.999073        4498
# 1     91206             31297  34.162515 -118.203869       31297
# 2     92627             62069  33.645672 -117.922613       62069
# 3     94553             46677  38.014457 -122.115432       46677
# 4     93010             42853  34.227846 -119.079903       42853
#
#    monthly_charge
# 0            65.6
# 1            59.9
# 2            73.9
# 3            98.0
# 4            83.9

# %%
# Hiển thị toàn bộ các cột khi xem dữ liệu
pd.set_option('display.max_columns', None)

# Hiển thị 5 dòng đầu tiên của dataset đã merge
df_merged.head()
# Out:
#   customer_id  gender  age under_30 senior_citizen partner dependents  \
# 0  0002-ORFBO  Female   37       No             No     Yes         No
# 1  0003-MKNFE    Male   46       No             No      No         No
# 2  0004-TLHLJ    Male   50       No             No      No         No
# 3  0011-IGKFF    Male   78       No            Yes     Yes         No
# 4  0013-EXCHZ  Female   75       No            Yes     Yes         No
#
#    number_of_dependents married  tenure internet_service phone_service  \
# 0                     0     Yes       9              Yes           Yes
# 1                     0      No       9              Yes           Yes
# 2                     0      No       4              Yes           Yes
# 3                     0     Yes      13              Yes           Yes
# 4                     0     Yes       3              Yes           Yes
#
#   multiple_lines  avg_monthly_gb_download unlimited_data    offer  \
# 0             No                       16            Yes     None
# 1            Yes                       10             No     None
# 2             No                       30            Yes  Offer E
# 3             No                        4            Yes  Offer D
# 4             No                       11            Yes     None
#
#   referred_a_friend  number_of_referrals online_security online_backup  \
# 0               Yes                    2              No           Yes
# 1                No                    0              No            No
# 2                No                    0              No            No
# 3               Yes                    1              No           Yes
# 4               Yes                    3              No            No
#
#   device_protection premium_tech_support streaming_tv streaming_movies  \
# 0                No                  Yes          Yes               No
# 1                No                   No           No              Yes
# 2               Yes                   No           No               No
# 3               Yes                   No          Yes              Yes
# 4                No                  Yes          Yes               No
#
#   streaming_music internet_type        contract paperless_billing  \
# 0              No         Cable        One Year               Yes
# 1             Yes         Cable  Month-to-Month                No
# 2              No   Fiber Optic  Month-to-Month               Yes
# 3              No   Fiber Optic  Month-to-Month               Yes
# 4              No   Fiber Optic  Month-to-Month               Yes
#
#      payment_method  monthly__charges  avg_monthly_long_distance_charges  \
# 0      Mailed check              65.6                              42.39
# 1      Mailed check              59.9                              10.69
# 2  Electronic check              73.9                              33.65
# 3  Electronic check              98.0                              27.82
# 4      Mailed check              83.9                               7.38
#
#    total_charges  total_refunds  total_extra_data_charges  \
# 0         593.30           0.00                         0
# 1         542.40          38.33                        10
# 2         280.85           0.00                         0
# 3        1237.85           0.00                         0
# 4         267.40           0.00                         0
#
#    total_long_distance_charges  total_revenue  satisfaction_score  cltv  \
# 0                       381.51         974.81                   3  2205
# 1                        96.21         610.28                   5  5414
# 2                       134.60         415.45                   1  4479
# 3                       361.66        1599.51                   1  3714
# 4                        22.14         289.54                   1  3464
#
#   customer_status  churn_score churn_label  churn_value   churn_category  \
# 0          Stayed           65          No            0   Not Applicable
# 1          Stayed           66          No            0   Not Applicable
# 2         Churned           71         Yes            1       Competitor
# 3         Churned           91         Yes            1  Dissatisfaction
# 4         Churned           68         Yes            1  Dissatisfaction
#
#                     churn_reason        country       state          city  \
# 0                            NaN  United States  California  Frazier Park
# 1                            NaN  United States  California      Glendale
# 2  Competitor had better devices  United States  California    Costa Mesa
# 3        Product dissatisfaction  United States  California      Martinez
# 4            Network reliability  United States  California     Camarillo
#
#    zip_code  total_population   latitude   longitude  population  \
# 0     93225              4498  34.827662 -118.999073        4498
# 1     91206             31297  34.162515 -118.203869       31297
# 2     92627             62069  33.645672 -117.922613       62069
# 3     94553             46677  38.014457 -122.115432       46677
# 4     93010             42853  34.227846 -119.079903       42853
#
#    monthly_charge
# 0            65.6
# 1            59.9
# 2            73.9
# 3            98.0
# 4            83.9

# %%
# Xóa hai cột "monthly_charge" và "population" khỏi df_merged
df_merged = df_merged.drop(columns=["monthly_charge", "population"])

# Xuất dữ liệu đã cập nhật ra file CSV mới
merged_file_path = "dataset/Merged_Churn_Dataset.csv"
df_merged.to_csv(merged_file_path, index=False)

# Hiển thị 5 dòng đầu tiên của dữ liệu sau khi xóa cột
df_merged.head()
# Out:
#   customer_id  gender  age under_30 senior_citizen partner dependents  \
# 0  0002-ORFBO  Female   37       No             No     Yes         No
# 1  0003-MKNFE    Male   46       No             No      No         No
# 2  0004-TLHLJ    Male   50       No             No      No         No
# 3  0011-IGKFF    Male   78       No            Yes     Yes         No
# 4  0013-EXCHZ  Female   75       No            Yes     Yes         No
#
#    number_of_dependents married  tenure internet_service phone_service  \
# 0                     0     Yes       9              Yes           Yes
# 1                     0      No       9              Yes           Yes
# 2                     0      No       4              Yes           Yes
# 3                     0     Yes      13              Yes           Yes
# 4                     0     Yes       3              Yes           Yes
#
#   multiple_lines  avg_monthly_gb_download unlimited_data    offer  \
# 0             No                       16            Yes     None
# 1            Yes                       10             No     None
# 2             No                       30            Yes  Offer E
# 3             No                        4            Yes  Offer D
# 4             No                       11            Yes     None
#
#   referred_a_friend  number_of_referrals online_security online_backup  \
# 0               Yes                    2              No           Yes
# 1                No                    0              No            No
# 2                No                    0              No            No
# 3               Yes                    1              No           Yes
# 4               Yes                    3              No            No
#
#   device_protection premium_tech_support streaming_tv streaming_movies  \
# 0                No                  Yes          Yes               No
# 1                No                   No           No              Yes
# 2               Yes                   No           No               No
# 3               Yes                   No          Yes              Yes
# 4                No                  Yes          Yes               No
#
#   streaming_music internet_type        contract paperless_billing  \
# 0              No         Cable        One Year               Yes
# 1             Yes         Cable  Month-to-Month                No
# 2              No   Fiber Optic  Month-to-Month               Yes
# 3              No   Fiber Optic  Month-to-Month               Yes
# 4              No   Fiber Optic  Month-to-Month               Yes
#
#      payment_method  monthly__charges  avg_monthly_long_distance_charges  \
# 0      Mailed check              65.6                              42.39
# 1      Mailed check              59.9                              10.69
# 2  Electronic check              73.9                              33.65
# 3  Electronic check              98.0                              27.82
# 4      Mailed check              83.9                               7.38
#
#    total_charges  total_refunds  total_extra_data_charges  \
# 0         593.30           0.00                         0
# 1         542.40          38.33                        10
# 2         280.85           0.00                         0
# 3        1237.85           0.00                         0
# 4         267.40           0.00                         0
#
#    total_long_distance_charges  total_revenue  satisfaction_score  cltv  \
# 0                       381.51         974.81                   3  2205
# 1                        96.21         610.28                   5  5414
# 2                       134.60         415.45                   1  4479
# 3                       361.66        1599.51                   1  3714
# 4                        22.14         289.54                   1  3464
#
#   customer_status  churn_score churn_label  churn_value   churn_category  \
# 0          Stayed           65          No            0   Not Applicable
# 1          Stayed           66          No            0   Not Applicable
# 2         Churned           71         Yes            1       Competitor
# 3         Churned           91         Yes            1  Dissatisfaction
# 4         Churned           68         Yes            1  Dissatisfaction
#
#                     churn_reason        country       state          city  \
# 0                            NaN  United States  California  Frazier Park
# 1                            NaN  United States  California      Glendale
# 2  Competitor had better devices  United States  California    Costa Mesa
# 3        Product dissatisfaction  United States  California      Martinez
# 4            Network reliability  United States  California     Camarillo
#
#    zip_code  total_population   latitude   longitude
# 0     93225              4498  34.827662 -118.999073
# 1     91206             31297  34.162515 -118.203869
# 2     92627             62069  33.645672 -117.922613
# 3     94553             46677  38.014457 -122.115432
# 4     93010             42853  34.227846 -119.079903

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 51 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   customer_id                        7043 non-null   object
#  1   gender                             7043 non-null   object
#  2   age                                7043 non-null   int64
#  3   under_30                           7043 non-null   object
#  4   senior_citizen                     7043 non-null   object
#  5   partner                            7043 non-null   object
#  6   dependents                         7043 non-null   object
#  7   number_of_dependents               7043 non-null   int64
#  8   married                            7043 non-null   object
#  9   tenure                             7043 non-null   int64
#  10  internet_service                   7043 non-null   object
#  11  phone_service                      7043 non-null   object
#  12  multiple_lines                     7043 non-null   object
#  13  avg_monthly_gb_download            7043 non-null   int64
#  14  unlimited_data                     7043 non-null   object
#  15  offer                              7043 non-null   object
#  16  referred_a_friend                  7043 non-null   object
#  17  number_of_referrals                7043 non-null   int64
#  18  online_security                    7043 non-null   object
#  19  online_backup                      7043 non-null   object
#  20  device_protection                  7043 non-null   object
#  21  premium_tech_support               7043 non-null   object
#  22  streaming_tv                       7043 non-null   object
#  23  streaming_movies                   7043 non-null   object
#  24  streaming_music                    7043 non-null   object
#  25  internet_type                      7043 non-null   object
#  26  contract                           7043 non-null   object
#  27  paperless_billing                  7043 non-null   object
#  28  payment_method                     7043 non-null   object
#  29  monthly__charges                   7043 non-null   float64
#  30  avg_monthly_long_distance_charges  7043 non-null   float64
#  31  total_charges                      7043 non-null   float64
#  32  total_refunds                      7043 non-null   float64
#  33  total_extra_data_charges           7043 non-null   int64
#  34  total_long_distance_charges        7043 non-null   float64
#  35  total_revenue                      7043 non-null   float64
#  36  satisfaction_score                 7043 non-null   int64
#  37  cltv                               7043 non-null   int64
#  38  customer_status                    7043 non-null   object
#  39  churn_score                        7043 non-null   int64
#  40  churn_label                        7043 non-null   object
#  41  churn_value                        7043 non-null   int64
#  42  churn_category                     7043 non-null   object
#  43  churn_reason                       1869 non-null   object
#  44  country                            7043 non-null   object
#  45  state                              7043 non-null   object
#  46  city                               7043 non-null   object
#  47  zip_code                           7043 non-null   int64
#  48  total_population                   7043 non-null   int64
#  49  latitude                           7043 non-null   float64
#  50  longitude                          7043 non-null   float64
# dtypes: float64(8), int64(12), object(31)
# memory usage: 2.8+ MB
